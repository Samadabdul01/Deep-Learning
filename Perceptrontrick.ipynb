# %%
from sklearn.datasets import make_classification
X,y = make_classification(n_samples=100, n_features=2, n_informative=1, n_redundant=0, n_classes=2, random_state = 41, n_clusters_per_class=1,
                          hypercube=False, class_sep= 10)
# X, y = make_classification(n_samples=100, n_features=2, n_informative=1,n_redundant=0,
#                            n_classes=2, n_clusters_per_class=1, random_state=41,hypercube=False,class_sep=10)

# %%
X.shape,y.shape
# Out:
# ((100, 2), (100,))

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,6))
plt.scatter(X[:,0],X[:,1],c=y)

# %%
def step(a):
    return 1 if a>=0 else 0

# %%
import numpy as np
def perceptron(X,y):
    X = np.insert(X,0,1,axis=1)
    weights = np.ones(X.shape[1])
    lr = 0.1
    for i in range(1000):
        j = np.random.randint(1,100)
        y_pred = step(np.dot(X[j],weights))
        weights = weights + lr*(y[j] - y_pred)*X[j]
    return weights[0], weights[1:]

# %%
intercept, coef = perceptron(X,y)

# %%
print("Intercept is: ",intercept)
print("coefficient is: ",coef)
# Out:
# Intercept is:  0.9
# coefficient is:  [1.2784679 0.1676242]

# %%
m = coef[0]/coef[1]
b = intercept/coef[1]
print("m = ",m)
print("b = ",b)
# Out:
# m =  7.626988893279906
# b =  5.369153198201539
